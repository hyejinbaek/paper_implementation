# %%
# 프리드먼 테스트
import os
from scipy import stats
import pandas as pd
from scipy.stats import friedmanchisquare

# %%
# 데이터 로드
df = pd.read_csv('./res/6_chess_ensemble_method_res.csv')
# ± 표기 제거
df['Accuracy'] = df['Accuracy'].str.split(' ±').str[0].astype(float)

# 5개의 메서드 선택
methods_of_interest = ['8_dynamic + datawig + knn', 'datawig', 'dynamic', 'knn', 'zero']
df_selected_methods = df[df['method'].isin(methods_of_interest)]

# %%
# 프리드먼 검정을 위한 데이터 구성
data = []
for method in methods_of_interest:
    method_data = df_selected_methods[df_selected_methods['method'] == method]['Accuracy'].values
    data.append(method_data)

print(data)
# Out:
# [array([0.9493, 0.9509, 0.951 , 0.95  , 0.9492, 0.9494, 0.9494, 0.9497,
#        0.9502, 0.9502, 0.9498, 0.9496, 0.9495, 0.9491, 0.9491, 0.9493,
#        0.9491, 0.9491, 0.9491, 0.9489, 0.9489, 0.949 , 0.9488, 0.9488,
#        0.9488, 0.9489, 0.9489, 0.9487, 0.9488, 0.9487]), array([0.0497, 0.0481, 0.0481, 0.0529, 0.0554, 0.0535, 0.0519, 0.0479,
#        0.0447, 0.051 , 0.0538, 0.0536, 0.0515, 0.059 , 0.051 , 0.0487,
#        0.056 , 0.0504, 0.0535, 0.0561, 0.0494, 0.0497, 0.0554, 0.0513,
#        0.0542, 0.0503, 0.0474, 0.0544, 0.0519, 0.0524]), array([0.2092, 0.2183, 0.2132, 0.2222, 0.2021, 0.2076, 0.2123, 0.2   ,
#        0.2069, 0.2042, 0.2144, 0.2158, 0.2105, 0.2121, 0.2155, 0.2126,
#        0.2144, 0.2007, 0.2099, 0.2096, 0.2123, 0.2091, 0.2121, 0.221 ,
#        0.216 , 0.2142, 0.2139, 0.2133, 0.2098, 0.2055]), array([0.0497, 0.0481, 0.0481, 0.0529, 0.0554, 0.0535, 0.0519, 0.0479,
#        0.0447, 0.051 , 0.0538, 0.0536, 0.0515, 0.059 , 0.051 , 0.0487,
#        0.056 , 0.0504, 0.0535, 0.0561, 0.0494, 0.0497, 0.0554, 0.0513,
#        0.0542, 0.0503, 0.0474, 0.0544, 0.0519, 0.0524]), array([0.0497, 0.0481, 0.0481, 0.0529, 0.0554, 0.0535, 0.0519, 0.0479,
#        0.0447, 0.051 , 0.0538, 0.0536, 0.0515, 0.059 , 0.051 , 0.0487,
#        0.056 , 0.0504, 0.0535, 0.0561, 0.0494, 0.0497, 0.0554, 0.0513,
#        0.0542, 0.0503, 0.0474, 0.0544, 0.0519, 0.0524])]

# %%
# 프리드먼 검정 수행
statistic, p_value = friedmanchisquare(*data)
# 결과 출력
print("Friedman Test Statistic:", statistic)
print("P-value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-b13a6e0bce40> in <module>
#       1 # 프리드먼 검정 수행
# ----> 2 statistic, p_value = friedmanchisquare(data)
#       3 # 결과 출력
#       4 print("Friedman Test Statistic:", statistic)
#       5 print("P-value:", p_value)
#
# ~/.local/lib/python3.8/site-packages/scipy/stats/_stats_py.py in friedmanchisquare(*samples)
#    8671     k = len(samples)
#    8672     if k < 3:
# -> 8673         raise ValueError('At least 3 sets of samples must be given '
#    8674                          'for Friedman test, got {}.'.format(k))
#    8675
#
# ValueError: At least 3 sets of samples must be given for Friedman test, got 1.
