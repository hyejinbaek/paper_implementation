# %%
# 프리드먼 테스트
import os
from scipy import stats
import pandas as pd
from scipy.stats import friedmanchisquare

# %%
# 데이터 로드
df = pd.read_csv('./res/23_ai4i_ensemble_method_res.csv')
# ± 표기 제거
df['Accuracy'] = df['Accuracy'].str.split(' ±').str[0].astype(float)

# 5개의 메서드 선택
methods_of_interest = ['8_dynamic + datawig + knn', 'datawig', 'dynamic', 'knn', 'zero']
df_selected_methods = df[df['method'].isin(methods_of_interest)]

# %%
# 프리드먼 검정을 위한 데이터 구성
data = []
for method in methods_of_interest:
    method_data = df_selected_methods[df_selected_methods['method'] == method]['Accuracy'].values
    data.append(method_data)

print(data)
# Out:
# [array([0.566 , 0.5626, 0.5629, 0.5612, 0.5615, 0.5624, 0.5613, 0.5618,
#        0.5618, 0.5607, 0.5603, 0.5599, 0.5593, 0.5593, 0.5596, 0.5604,
#        0.5602, 0.5604, 0.5602, 0.5602, 0.5602, 0.5605, 0.5603, 0.5603,
#        0.5603, 0.5604, 0.5603, 0.5604, 0.5601, 0.5604]), array([0.607 , 0.598 , 0.606 , 0.5945, 0.605 , 0.607 , 0.5905, 0.613 ,
#        0.5985, 0.579 , 0.5925, 0.5955, 0.5925, 0.5935, 0.5955, 0.615 ,
#        0.597 , 0.609 , 0.596 , 0.6055, 0.604 , 0.6055, 0.585 , 0.602 ,
#        0.596 , 0.6065, 0.596 , 0.5975, 0.5945, 0.6055]), array([0.4835, 0.4815, 0.479 , 0.48  , 0.4775, 0.488 , 0.483 , 0.47  ,
#        0.4885, 0.4945, 0.4845, 0.4755, 0.468 , 0.496 , 0.4975, 0.4915,
#        0.4745, 0.475 , 0.4785, 0.4705, 0.4745, 0.487 , 0.4955, 0.479 ,
#        0.4925, 0.4775, 0.4755, 0.4955, 0.473 , 0.4875]), array([0.607 , 0.598 , 0.606 , 0.5945, 0.605 , 0.607 , 0.5905, 0.613 ,
#        0.5985, 0.579 , 0.5925, 0.5955, 0.5925, 0.5935, 0.5955, 0.615 ,
#        0.597 , 0.609 , 0.596 , 0.6055, 0.604 , 0.6055, 0.585 , 0.602 ,
#        0.596 , 0.6065, 0.596 , 0.5975, 0.5945, 0.6055]), array([0.607 , 0.5975, 0.606 , 0.5945, 0.605 , 0.607 , 0.5905, 0.613 ,
#        0.5985, 0.579 , 0.5925, 0.5955, 0.5925, 0.5935, 0.5955, 0.615 ,
#        0.597 , 0.609 , 0.596 , 0.6055, 0.604 , 0.6055, 0.585 , 0.602 ,
#        0.596 , 0.6065, 0.596 , 0.5975, 0.5945, 0.6055])]

# %%
# 프리드먼 검정 수행
statistic, p_value = friedmanchisquare(*data)
# 결과 출력
print("Friedman Test Statistic:", statistic)
print("P-value:", p_value)
# Out:
# Friedman Test Statistic: 119.2795031055902
# P-value: 7.612764792181342e-25
